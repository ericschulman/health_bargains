# %%
using Pkg
using Distributions
using Optim
using PyPlot
using LinearAlgebra
Pkg.add("DataFrames")
Pkg.add("CSV")
using DataFrames
using CSV
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 %13.7 %>                             ]  27.4 %>              ]  64.8 %================================>        ]  78.5 %92.1 % Resolving package versions...
#  Installed DataValueInterfaces ───────── v1.0.0
#  Installed Compat ────────────────────── v3.6.0
#  Installed TableTraits ───────────────── v1.0.0
#  Installed Tables ────────────────────── v1.0.3
#  Installed PyCall ────────────────────── v1.91.4
#  Installed CategoricalArrays ─────────── v0.7.7
#  Installed StatsBase ─────────────────── v0.32.2
#  Installed DataFrames ────────────────── v0.20.2
#  Installed IteratorInterfaceExtensions ─ v1.0.0
#  Installed InvertedIndices ───────────── v1.0.0
#  Installed PooledArrays ──────────────── v0.5.3
#   Updating `~/.julia/environments/v1.0/Project.toml`
#   [a93c6f00] + DataFrames v0.20.2
# ...

# %%
data= CSV.read("data/Sequential.csv")

print(data)
# Out:
# 1000×11 DataFrame
# │ Row  │ alpha   │ hosp        │ phi1       │ s1       │ p1       │ profits1 │ phi2     │ s2       │ p2      │ profits2 │ Column11 │
# │      │ Float64 │ Float64     │ Float64    │ Float64  │ Float64  │ Float64  │ Float64  │ Float64  │ Float64 │ Float64  │ Missing  │
# ├──────┼─────────┼─────────────┼────────────┼──────────┼──────────┼──────────┼──────────┼──────────┼─────────┼──────────┼──────────┤
# │ 1    │ 0.7     │ 0.153879    │ 2.00004    │ 0.160653 │ 2.10201  │ 0.273431 │ 3.20866  │ 0.139648 │ 2.30218 │ 0.231878 │ missing  │
# │ 2    │ 0.7     │ 0.151403    │ 2.0        │ 0.16037  │ 2.10143  │ 0.272858 │ 3.0844   │ 0.141446 │ 2.28081 │ 0.235356 │ missing  │
# │ 3    │ 0.7     │ 0.177061    │ 2.50384    │ 0.154002 │ 2.18939  │ 0.260052 │ 3.75849  │ 0.132955 │ 2.39933 │ 0.219061 │ missing  │
# │ 4    │ 0.7     │ 0.225014    │ 3.94201    │ 0.135066 │ 2.44006  │ 0.223082 │ 4.95425  │ 0.119622 │ 2.61353 │ 0.194107 │ missing  │
# ...

# %%
function calc_objective(params,data)
    obj = [0,0]
    for i=data
        #calculate dpi1/dphi1
        #calculate dpi1/dphi2
        
        #caluclate dp/dphi1
        #calculate dp/dphi2
        
        #calculate ds/dphi1
        #calculate ds/dphi2
